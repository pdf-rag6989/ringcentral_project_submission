# %%
#!pip install pytesseract

# %%
import os
import base64
from openai import OpenAI
import fitz
import re
import pandas as pd
from img2table.document import PDF
from img2table.ocr import TesseractOCR
import json
import base64
import torch
from transformers import AutoProcessor, VisionEncoderDecoderModel
from PIL import Image
import fitz
import os
from pathlib import Path
import pytesseract
from logger import Logger
import warnings
warnings.filterwarnings('ignore')
from generic import GenericFunction
import ssl
import certifi
os.environ['CURL_CA_BUNDLE'] = './certificates/huggingface.co.pem'
ssl._create_default_https_context = ssl.create_default_context(cafile=certifi.where())

pytesseract.pytesseract.tesseract_cmd = r'/opt/homebrew/bin/tesseract'

class PDFProcessor:
    
    def __init__(self, file_mapping, openai_key,source_pdf_path="source_data", output_folder="data_parsed", images_folder="images", page_range=None):
        """
        Initializes the PDFProcessor class.
        """
        self.generic=GenericFunction
        self.logger = Logger()
        self.file_mapping = file_mapping
        self.source_pdf_path = source_pdf_path
        self.output_folder = output_folder
        self.page_range = page_range
        self.images_folder = images_folder
        self.page_range=page_range
        self.processor = AutoProcessor.from_pretrained("facebook/nougat-base")
        self.model = VisionEncoderDecoderModel.from_pretrained("facebook/nougat-base")
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model.to(self.device)
        self.api_key = openai_key
        self.client = OpenAI(api_key=self.api_key)
        self.prompt= self.read_prompt("./prompts/pdf_parsing.txt")
        self.logger.log_info("The prompt is {}".format(self.prompt))


    def read_prompt(self,file_path):
        with open(file_path, 'r') as file:
            return file.read().strip()
            
    def get_or_download_pdfs(self):
        """
        Checks if all PDFs and their OCR versions exist locally. Downloads PDFs if not available.
        """
        os.makedirs(self.source_pdf_path, exist_ok=True)
        original_files = []
        ocr_files = []
    
        for mapping in self.file_mapping:
            for url, file_name in mapping.items():
                local_path = os.path.join(self.source_pdf_path, file_name)
                ocr_path = os.path.join(self.source_pdf_path, file_name.replace(".pdf", "_OCR.pdf"))
    
                if os.path.exists(ocr_path):
                    self.logger.log_info(f"OCR version of the PDF exists locally at: {ocr_path}")
                    ocr_files.append(ocr_path)
                else:
                    self.logger.log_info(f"OCR version not found for: {file_name}. Ensure OCR processing is done.")
    
                if os.path.exists(local_path):
                    self.logger.log_info(f"Original PDF already exists locally at: {local_path}")
                    original_files.append(local_path)
                else:
                    self.logger.log_info(f"Downloading PDF from URL: {url}")
                    response = requests.get(url)
                    if response.status_code == 200:
                        with open(local_path, "wb") as f:
                            f.write(response.content)
                        self.logger.log_info(f"Downloaded PDF to: {local_path}")
                        original_files.append(local_path)
                    else:
                        self.logger.log_error(f"Failed to download PDF from {url}")
                        raise Exception(f"Failed to download PDF. HTTP Status Code: {response.status_code}")
    
        return original_files, ocr_files


    def clean_text(self, text):
        """
        Cleans the input text by joining lines and handling non-string inputs.
        """
        if not isinstance(text, str):
            return str(text) if text is not None else "" 
        lines = text.split("\n")
        cleaned_lines = []
        buffer = ""  
        for line in lines:
            line = line.strip()
            if not line:
                continue
            if re.search(r"[.!?]$", line) or line.startswith("*"):
                if buffer:
                    cleaned_lines.append(buffer.strip())
                    buffer = ""
                cleaned_lines.append(line)
            else:
                buffer += " " + line
        if buffer:
            cleaned_lines.append(buffer.strip())
        return "\n".join(cleaned_lines)


    def dataframe_json_to_continuous_text(self,json_list):
        """
        Converts a list of JSON objects (representing DataFrame tables) into continuous text.
        """
        continuous_text = []
        for idx, table_json in enumerate(json_list, start=1):
            if isinstance(table_json, str):
                try:
                    table_json = json.loads(table_json)
                except json.JSONDecodeError:
                    raise ValueError(f"Invalid JSON string at index {idx}: {table_json}")
            if not isinstance(table_json, list) or not all(isinstance(row, dict) for row in table_json):
                raise ValueError(f"Invalid table format at index {idx}: Expected a list of dictionaries.")
            table_label = f"Table {idx}: "
            row_texts = []   
            for row in table_json:
                row_text = ", ".join(f"{key} is {value}" for key, value in row.items())
                row_texts.append(row_text)
            combined_table_text = table_label + " | ".join(row_texts)
            continuous_text.append(combined_table_text)
        return "\n".join(continuous_text)


    def encode_image(self,image_path):
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')

    def analyze_image_with_openai(self,image_path, openai_model="gpt-4o-mini"):
        """
        Analyzes the content of an image using OpenAI GPT model.
        """
        base64_image = self.encode_image(image_path)
        response = self.client.chat.completions.create(
            model=openai_model,
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": self.prompt},
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}},
                    ],
                }
            ],
            max_tokens=500,
        )
        return response.choices[0].message.content

    def extract_images(self,pdf_path, output_folder="images", dpi=300):
        """
        Extracts full-page and sub-images from a PDF and organizes them in a structured folder.
        """
        pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]
        pdf_folder = os.path.join(output_folder, pdf_name)
        os.makedirs(pdf_folder, exist_ok=True)
        doc = fitz.open(pdf_path)
        image_details = {}
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            page_folder = os.path.join(pdf_folder, f"page-{page_num + 1}")
            os.makedirs(page_folder, exist_ok=True)
            pix = page.get_pixmap(dpi=dpi)
            full_page_image_path = os.path.join(page_folder, "full_page_image.png")
            pix.save(full_page_image_path)
            sub_image_paths = []
            for img_index, img in enumerate(page.get_images(full=True), start=1):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                ext = base_image["ext"]
    
                # Save the sub-image with a detailed name
                sub_image_name = f"page_{page_num + 1}_sub_image_{img_index}.{ext}"
                sub_image_path = os.path.join(page_folder, sub_image_name)
                with open(sub_image_path, "wb") as img_file:
                    img_file.write(image_bytes)
                sub_image_paths.append(os.path.relpath(sub_image_path, start=os.getcwd()))
            image_details[f"page-{page_num + 1}"] = {
                "full_page_image": os.path.relpath(full_page_image_path, start=os.getcwd()),
                "sub_images": sub_image_paths,
            }
    
        return image_details


    def extract_text_from_image(self,image_path):
        image = Image.open(image_path)
        pixel_values = self.processor(images=image, return_tensors="pt").pixel_values.to(self.device)
        outputs = self.model.generate(pixel_values, max_length=512, early_stopping=True)
        generated_text = self.processor.batch_decode(outputs, skip_special_tokens=True)[0]
        return generated_text.strip()

    def extract_text_from_page(self,pdf_path, page_num):
        image_path = self.rasterize_page(pdf_path, page_num)
        extracted_text = self.extract_text_from_image(image_path)
        return extracted_text

    def save_tables_to_excel(self,pdf_path, excel_path="tables.xlsx"):
        """
        Extract all tables from the PDF and save them into an Excel file.
        """
        pdf = PDF(src=pdf_path)
        ocr = TesseractOCR(lang="eng")
        pdf.to_xlsx(excel_path, ocr=ocr)


    def extract_tables_from_excel(self,excel_path, page_num):
        """
        Extract and clean all tables for a specific page from the Excel file.
        """
        tables = []
        page_name = f"Page {page_num}"
        with pd.ExcelFile(excel_path) as xls:
            for sheet_name in xls.sheet_names:
                if sheet_name.split(" - ")[0].strip() == page_name:
                    df = pd.read_excel(xls, sheet_name=sheet_name)
                    df = df.applymap(self.clean_text)
                    tables.append(df.to_json(orient="records"))
        return tables
    
    def extract_page_title_from_header(self,page, y_threshold=100):
        blocks = page.get_text("dict")["blocks"]
        top_texts = []
        for block in blocks:
            if "lines" in block and block["bbox"][1] < y_threshold:
                for line in block["lines"]:
                    for span in line["spans"]:
                        top_texts.append(span["text"])
        full_title = " ".join(top_texts).strip()
        cleaned_title = re.sub(r"[^a-zA-Z0-9\s&]", "", full_title)
        words = cleaned_title.split()
        if len(words) > 1:
            if words[1].lower() in {"and", "&"} and len(words) > 2:
                return f"{words[0]} {words[1]} {words[2]}"
            return f"{words[0]} {words[1]}"
        return words[0] if words else f"Page {page.number + 1}"


    def rasterize_page(self, pdf_path, page_num, dpi=96):
        """
        Converts a page to an image and saves it under the respective PDF folder.
        """
        pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]
        pdf_folder = os.path.join(self.images_folder, pdf_name)
        os.makedirs(pdf_folder, exist_ok=True)
        page_folder = os.path.join(pdf_folder, f"page-{page_num + 1}")
        os.makedirs(page_folder, exist_ok=True)
    
        # Generate the full-page image
        pdf = fitz.open(pdf_path)
        page = pdf.load_page(page_num)
        pix = page.get_pixmap(dpi=dpi)
        full_page_image_path = os.path.join(page_folder, "rasterized_full_page_image.png")
        pix.save(full_page_image_path)
        return full_page_image_path

    def get_text_tesseract(self,filename):
        image = Image.open(filename)
        text = pytesseract.image_to_string(image)
        return self.clean_text(text)
        
    
    def process_pdf(self,pdf_path,ocr_pdf,excel_path,image_pdf_path="images", ):
        """
        Processes a PDF and extracts metadata, text, tables, and images into a DataFrame.
        """
    
        doc = fitz.open(pdf_path)
        metadata = doc.metadata
        doc_title = metadata.get("title", "Unknown Title")
        doc_author = metadata.get("author", "Unknown Author")
    
        image_details = self.extract_images(pdf_path, output_folder=image_pdf_path)
        self.save_tables_to_excel(pdf_path, excel_path)
    
        page_data = []
        if self.page_range:
            page_num,total_pages=self.page_range
        else:
            page_num=0
            total_pages=len(doc)
        for page_num in range(total_pages):
            self.logger.log_info("Ruuning for PDF : {} and page number {}".format(pdf_path,page_num))
            page = doc[page_num]
            page_title = self.extract_page_title_from_header(page)  
            page_tables = self.extract_tables_from_excel(excel_path, page_num + 1)
            extracted_text = self.extract_text_from_page(ocr_pdf, page_num)
            page_image_details = image_details.get(f"page-{page_num + 1}", {})
            full_page_image = page_image_details.get("full_page_image", "")
            extracted_text_tesseract=self.get_text_tesseract(full_page_image)
            sub_images = page_image_details.get("sub_images", [])
            image_description=""
            if len(sub_images)>0:
                self.logger.log_info("Getting image description for path {}".format(full_page_image))
                image_description=self.analyze_image_with_openai(full_page_image)
                #print("The image description is {}".format(image_description))
            all_images = [full_page_image] + sub_images
            table_description=self.dataframe_json_to_continuous_text(page_tables)
            combined_text = f"{extracted_text_tesseract}\n\n"
            combined_text += f"Image Details:\n{image_description}\n\n" if image_description else ""
            combined_text += f"Table Details:\n{table_description}" if table_description else ""
            page_data.append({
                "PDF Name": os.path.basename(pdf_path),
                "Page Number": page_num + 1,
                "Page Title": page_title,
                "Combined Text":combined_text,
                "Page Text": extracted_text,
                "Page Text(Tesseract)": extracted_text_tesseract,
                "All Image Paths": all_images,
                "Full Page Image Path": full_page_image,
                "Sub Image Paths": sub_images,
                "Image Description": image_description,
                "Table JSON": page_tables,
                "Table Description": table_description
            })
    
        df = pd.DataFrame(page_data)
        return df



def main():
    combined_data = []
    from generic import GenericFunction
    generic = GenericFunction()
    file_mapping = generic.get_value("file_mappings")
    open_ai_key = generic.get_value("api_keys")['openai']
    page_range = None 
    processor = PDFProcessor(file_mapping,open_ai_key, page_range=page_range)
    original_files, ocr_files = processor.get_or_download_pdfs()
    for original_pdf, ocr_pdf in zip(original_files, ocr_files):
        excel_path = f"data_parsed/{os.path.basename(original_pdf).replace('.pdf', '_tables.xlsx')}"
        pdf_df = processor.process_pdf(original_pdf, ocr_pdf, excel_path,"./images")
        combined_data.append(pdf_df)   
    final_combined_df = pd.concat(combined_data, ignore_index=True)
    output_path = "data_parsed/Combined_Output.csv"
    final_combined_df.to_csv(output_path, index=False)
    print(f"Processed all PDFs and saved consolidated output: {output_path}")

# %%
import os
if __name__ == "__main__":
    main()
# Out:
# 2024-11-24 16:32:12,874 [INFO] Loaded config.json from: /Users/deepakn/Desktop/PDF-RAG/config.json
# Config of the encoder: <class 'transformers.models.donut.modeling_donut_swin.DonutSwinModel'> is overwritten by shared encoder config: DonutSwinConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "depths": [
#     2,
#     2,
#     14,
#     2
#   ],
#   "drop_path_rate": 0.1,
#   "embed_dim": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1024,
#   "image_size": [
#     896,
#     672
#   ],
#   "initializer_range": 0.02,
#   "layer_norm_eps": 1e-05,
#   "mlp_ratio": 4.0,
#   "model_type": "donut-swin",
#   "num_channels": 3,
#   "num_heads": [
#     4,
#     8,
#     16,
#     32
#   ],
#   "num_layers": 4,
#   "patch_size": 4,
#   "qkv_bias": true,
#   "transformers_version": "4.47.0.dev0",
#   "use_absolute_embeddings": false,
#   "window_size": 7
# }
#
# Config of the decoder: <class 'transformers.models.mbart.modeling_mbart.MBartForCausalLM'> is overwritten by shared decoder config: MBartConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "add_final_layer_norm": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 10,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "forced_eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "is_encoder_decoder": false,
#   "max_position_embeddings": 4096,
#   "model_type": "mbart",
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "scale_embedding": true,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.47.0.dev0",
#   "use_cache": true,
#   "vocab_size": 50000
# }
#
# 2024-11-24 16:32:25,856 [INFO] The prompt is Analyze the given image from a car manual and provide a detailed description in a continuous text format. The description should include:
# 1. The type of content in the image (e.g., diagram, instruction, warning sign, specification chart).
# 2. A detailed description of the main components, labels, or features visible in the image (e.g., engine parts, dashboard controls, tire specifications).
# 3. Any numerical data or specifications present in the image (e.g., torque values, pressure limits, dimensions, part numbers).
# 4. Any instructional steps, safety guidelines, or warnings included in the image.
# 5. The context or purpose of the image (e.g., troubleshooting, installation, maintenance).
# 6. Key insights or critical information that would be useful for retrieval or understanding.
#
# The output should be in a single paragraph in max 200 words, written in clear and concise language, optimized for embedding in a retrieval system. Also, the focus should be on the image and its relative content, not other text elements.
# 2024-11-24 16:32:25,858 [INFO] OCR version of the PDF exists locally at: source_data/Astor Manual_OCR.pdf
# 2024-11-24 16:32:25,859 [INFO] Original PDF already exists locally at: source_data/Astor Manual.pdf
# 2024-11-24 16:32:25,859 [INFO] OCR version of the PDF exists locally at: source_data/APP-TIAGO-FINAL-OMSB_OCR.pdf
# 2024-11-24 16:32:25,860 [INFO] Original PDF already exists locally at: source_data/APP-TIAGO-FINAL-OMSB.pdf
# tesseract 5.5.0
#  leptonica-1.85.0
#   libgif 5.2.2 : libjpeg 8d (libjpeg-turbo 3.0.4) : libpng 1.6.44 : libtiff 4.7.0 : zlib 1.2.12 : libwebp 1.4.0 : libopenjp2 2.5.2
#  Found NEON
#  Found libarchive 3.7.7 zlib/1.2.12 liblzma/5.6.3 bz2lib/1.0.8 liblz4/1.10.0 libzstd/1.5.6
#  Found libcurl/8.6.0 SecureTransport (LibreSSL/3.3.6) zlib/1.2.12 nghttp2/1.61.0
# 2024-11-24 16:33:12,045 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 0
# 2024-11-24 16:33:25,963 [INFO] Getting image description for path images/Astor Manual/page-1/full_page_image.png
# 2024-11-24 16:33:31,599 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:33:31,621 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 1
# 2024-11-24 16:33:45,845 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 2
# 2024-11-24 16:33:53,131 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 3
# 2024-11-24 16:34:06,693 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 4
# 2024-11-24 16:34:21,578 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 5
# 2024-11-24 16:34:37,191 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 6
# 2024-11-24 16:34:52,654 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 7
# 2024-11-24 16:35:08,248 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 8
# 2024-11-24 16:35:23,875 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 9
# 2024-11-24 16:35:37,601 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 10
# 2024-11-24 16:35:49,529 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 11
# 2024-11-24 16:35:54,874 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 12
# 2024-11-24 16:36:09,475 [INFO] Getting image description for path images/Astor Manual/page-13/full_page_image.png
# 2024-11-24 16:36:14,148 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:36:14,170 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 13
# 2024-11-24 16:36:21,405 [INFO] Getting image description for path images/Astor Manual/page-14/full_page_image.png
# 2024-11-24 16:36:27,395 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:36:27,400 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 14
# 2024-11-24 16:36:33,824 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 15
# 2024-11-24 16:36:41,950 [INFO] Getting image description for path images/Astor Manual/page-16/full_page_image.png
# 2024-11-24 16:36:49,467 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:36:49,479 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 16
# 2024-11-24 16:36:52,804 [INFO] Getting image description for path images/Astor Manual/page-17/full_page_image.png
# 2024-11-24 16:36:59,031 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:36:59,037 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 17
# 2024-11-24 16:37:14,787 [INFO] Getting image description for path images/Astor Manual/page-18/full_page_image.png
# 2024-11-24 16:37:19,692 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:37:19,699 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 18
# 2024-11-24 16:37:35,124 [INFO] Getting image description for path images/Astor Manual/page-19/full_page_image.png
# 2024-11-24 16:37:42,538 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:37:42,548 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 19
# 2024-11-24 16:37:58,024 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 20
# 2024-11-24 16:38:13,626 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 21
# 2024-11-24 16:38:16,731 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 22
# 2024-11-24 16:38:19,446 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 23
# 2024-11-24 16:38:22,506 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 24
# 2024-11-24 16:38:27,269 [INFO] Getting image description for path images/Astor Manual/page-25/full_page_image.png
# 2024-11-24 16:38:33,310 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:38:33,321 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 25
# 2024-11-24 16:38:40,168 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 26
# 2024-11-24 16:38:54,839 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 27
# 2024-11-24 16:38:58,127 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 28
# 2024-11-24 16:39:11,896 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 29
# 2024-11-24 16:39:20,257 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 30
# 2024-11-24 16:39:34,904 [INFO] Getting image description for path images/Astor Manual/page-31/full_page_image.png
# 2024-11-24 16:39:40,771 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:39:40,780 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 31
# 2024-11-24 16:39:57,747 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 32
# 2024-11-24 16:40:12,187 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 33
# 2024-11-24 16:40:24,183 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 34
# 2024-11-24 16:40:35,247 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 35
# 2024-11-24 16:40:40,005 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 36
# 2024-11-24 16:40:47,162 [INFO] Getting image description for path images/Astor Manual/page-37/full_page_image.png
# 2024-11-24 16:40:53,730 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:40:53,743 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 37
# 2024-11-24 16:41:03,227 [INFO] Getting image description for path images/Astor Manual/page-38/full_page_image.png
# 2024-11-24 16:41:09,300 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:41:09,314 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 38
# 2024-11-24 16:41:24,031 [INFO] Getting image description for path images/Astor Manual/page-39/full_page_image.png
# 2024-11-24 16:41:31,402 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:41:31,410 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 39
# 2024-11-24 16:41:42,981 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 40
# 2024-11-24 16:41:58,411 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 41
# 2024-11-24 16:42:10,027 [INFO] Getting image description for path images/Astor Manual/page-42/full_page_image.png
# 2024-11-24 16:42:16,838 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:42:16,851 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 42
# 2024-11-24 16:42:22,238 [INFO] Getting image description for path images/Astor Manual/page-43/full_page_image.png
# 2024-11-24 16:42:28,765 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:42:28,773 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 43
# 2024-11-24 16:42:37,565 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 44
# 2024-11-24 16:42:43,583 [INFO] Getting image description for path images/Astor Manual/page-45/full_page_image.png
# 2024-11-24 16:42:49,067 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:42:49,080 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 45
# 2024-11-24 16:42:53,278 [INFO] Getting image description for path images/Astor Manual/page-46/full_page_image.png
# 2024-11-24 16:42:59,136 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:42:59,141 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 46
# 2024-11-24 16:43:07,788 [INFO] Getting image description for path images/Astor Manual/page-47/full_page_image.png
# 2024-11-24 16:43:11,968 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:43:11,984 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 47
# 2024-11-24 16:43:21,081 [INFO] Getting image description for path images/Astor Manual/page-48/full_page_image.png
# 2024-11-24 16:43:26,716 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:43:26,723 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 48
# 2024-11-24 16:43:34,818 [INFO] Getting image description for path images/Astor Manual/page-49/full_page_image.png
# 2024-11-24 16:43:40,165 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:43:40,181 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 49
# 2024-11-24 16:43:48,653 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 50
# 2024-11-24 16:43:56,395 [INFO] Getting image description for path images/Astor Manual/page-51/full_page_image.png
# 2024-11-24 16:44:02,118 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:44:02,137 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 51
# 2024-11-24 16:44:13,584 [INFO] Getting image description for path images/Astor Manual/page-52/full_page_image.png
# 2024-11-24 16:44:19,505 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:44:19,513 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 52
# 2024-11-24 16:44:35,197 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 53
# 2024-11-24 16:44:40,884 [INFO] Getting image description for path images/Astor Manual/page-54/full_page_image.png
# 2024-11-24 16:44:48,672 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:44:48,679 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 54
# 2024-11-24 16:44:53,967 [INFO] Getting image description for path images/Astor Manual/page-55/full_page_image.png
# 2024-11-24 16:44:59,668 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:44:59,684 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 55
# 2024-11-24 16:45:05,890 [INFO] Getting image description for path images/Astor Manual/page-56/full_page_image.png
# 2024-11-24 16:45:11,453 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:45:11,461 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 56
# 2024-11-24 16:45:15,036 [INFO] Getting image description for path images/Astor Manual/page-57/full_page_image.png
# 2024-11-24 16:45:21,437 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:45:21,451 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 57
# 2024-11-24 16:45:36,579 [INFO] Getting image description for path images/Astor Manual/page-58/full_page_image.png
# 2024-11-24 16:45:42,823 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:45:42,834 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 58
# 2024-11-24 16:45:47,210 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 59
# 2024-11-24 16:45:49,105 [INFO] Getting image description for path images/Astor Manual/page-60/full_page_image.png
# 2024-11-24 16:45:55,280 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:45:55,284 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 60
# 2024-11-24 16:46:00,867 [INFO] Getting image description for path images/Astor Manual/page-61/full_page_image.png
# 2024-11-24 16:46:06,103 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:46:06,150 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 61
# 2024-11-24 16:46:20,560 [INFO] Getting image description for path images/Astor Manual/page-62/full_page_image.png
# 2024-11-24 16:46:27,497 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:46:27,505 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 62
# 2024-11-24 16:46:33,742 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 63
# 2024-11-24 16:46:47,257 [INFO] Getting image description for path images/Astor Manual/page-64/full_page_image.png
# 2024-11-24 16:46:53,459 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:46:53,469 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 64
# 2024-11-24 16:47:05,872 [INFO] Getting image description for path images/Astor Manual/page-65/full_page_image.png
# 2024-11-24 16:47:11,092 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:47:11,104 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 65
# 2024-11-24 16:47:18,665 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 66
# 2024-11-24 16:47:22,677 [INFO] Getting image description for path images/Astor Manual/page-67/full_page_image.png
# 2024-11-24 16:47:26,551 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:47:26,559 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 67
# 2024-11-24 16:47:37,520 [INFO] Getting image description for path images/Astor Manual/page-68/full_page_image.png
# 2024-11-24 16:47:44,435 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:47:44,444 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 68
# 2024-11-24 16:47:55,243 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 69
# 2024-11-24 16:48:05,861 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 70
# 2024-11-24 16:48:08,301 [INFO] Getting image description for path images/Astor Manual/page-71/full_page_image.png
# 2024-11-24 16:48:14,858 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:48:14,872 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 71
# 2024-11-24 16:48:23,503 [INFO] Getting image description for path images/Astor Manual/page-72/full_page_image.png
# 2024-11-24 16:48:29,646 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:48:29,657 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 72
# 2024-11-24 16:48:44,128 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 73
# 2024-11-24 16:48:58,716 [INFO] Getting image description for path images/Astor Manual/page-74/full_page_image.png
# 2024-11-24 16:49:03,743 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:49:03,758 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 74
# 2024-11-24 16:49:11,019 [INFO] Getting image description for path images/Astor Manual/page-75/full_page_image.png
# 2024-11-24 16:49:16,513 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:49:16,521 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 75
# 2024-11-24 16:49:23,523 [INFO] Getting image description for path images/Astor Manual/page-76/full_page_image.png
# 2024-11-24 16:49:28,588 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:49:28,599 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 76
# 2024-11-24 16:49:38,724 [INFO] Getting image description for path images/Astor Manual/page-77/full_page_image.png
# 2024-11-24 16:49:44,362 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:49:44,371 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 77
# 2024-11-24 16:49:53,407 [INFO] Getting image description for path images/Astor Manual/page-78/full_page_image.png
# 2024-11-24 16:49:58,089 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:49:58,100 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 78
# 2024-11-24 16:50:12,726 [INFO] Getting image description for path images/Astor Manual/page-79/full_page_image.png
# 2024-11-24 16:50:17,874 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:50:17,918 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 79
# 2024-11-24 16:50:34,229 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 80
# 2024-11-24 16:50:48,198 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 81
# 2024-11-24 16:50:50,514 [INFO] Getting image description for path images/Astor Manual/page-82/full_page_image.png
# 2024-11-24 16:50:55,930 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:50:55,946 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 82
# 2024-11-24 16:51:09,847 [INFO] Getting image description for path images/Astor Manual/page-83/full_page_image.png
# 2024-11-24 16:51:15,110 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:51:15,120 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 83
# 2024-11-24 16:51:18,434 [INFO] Getting image description for path images/Astor Manual/page-84/full_page_image.png
# 2024-11-24 16:51:22,993 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:51:22,999 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 84
# 2024-11-24 16:51:28,237 [INFO] Getting image description for path images/Astor Manual/page-85/full_page_image.png
# 2024-11-24 16:51:32,631 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:51:32,636 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 85
# 2024-11-24 16:51:39,895 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 86
# 2024-11-24 16:51:42,554 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 87
# 2024-11-24 16:51:53,454 [INFO] Getting image description for path images/Astor Manual/page-88/full_page_image.png
# 2024-11-24 16:52:00,989 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:52:00,994 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 88
# 2024-11-24 16:52:05,873 [INFO] Getting image description for path images/Astor Manual/page-89/full_page_image.png
# 2024-11-24 16:52:11,582 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:52:11,599 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 89
# 2024-11-24 16:52:25,598 [INFO] Getting image description for path images/Astor Manual/page-90/full_page_image.png
# 2024-11-24 16:52:31,154 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:52:31,166 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 90
# 2024-11-24 16:52:42,912 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 91
# 2024-11-24 16:52:48,841 [INFO] Getting image description for path images/Astor Manual/page-92/full_page_image.png
# 2024-11-24 16:52:54,501 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:52:54,509 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 92
# 2024-11-24 16:53:04,011 [INFO] Getting image description for path images/Astor Manual/page-93/full_page_image.png
# 2024-11-24 16:53:12,515 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:53:12,531 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 93
# 2024-11-24 16:53:20,487 [INFO] Getting image description for path images/Astor Manual/page-94/full_page_image.png
# 2024-11-24 16:53:27,108 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:53:27,114 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 94
# 2024-11-24 16:53:36,168 [INFO] Getting image description for path images/Astor Manual/page-95/full_page_image.png
# 2024-11-24 16:53:43,865 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:53:43,875 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 95
# 2024-11-24 16:53:58,198 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 96
# 2024-11-24 16:54:05,020 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 97
# 2024-11-24 16:54:11,302 [INFO] Getting image description for path images/Astor Manual/page-98/full_page_image.png
# 2024-11-24 16:54:17,428 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:54:17,437 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 98
# 2024-11-24 16:54:26,240 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 99
# 2024-11-24 16:54:36,014 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 100
# 2024-11-24 16:54:50,033 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 101
# 2024-11-24 16:54:56,158 [INFO] Getting image description for path images/Astor Manual/page-102/full_page_image.png
# 2024-11-24 16:55:01,651 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:55:01,656 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 102
# 2024-11-24 16:55:07,711 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 103
# 2024-11-24 16:55:13,213 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 104
# 2024-11-24 16:55:24,674 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 105
# 2024-11-24 16:55:33,490 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 106
# 2024-11-24 16:55:41,645 [INFO] Getting image description for path images/Astor Manual/page-107/full_page_image.png
# 2024-11-24 16:55:45,895 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:55:45,905 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 107
# 2024-11-24 16:55:52,294 [INFO] Getting image description for path images/Astor Manual/page-108/full_page_image.png
# 2024-11-24 16:55:56,459 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:55:56,469 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 108
# 2024-11-24 16:56:10,605 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 109
# 2024-11-24 16:56:24,455 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 110
# 2024-11-24 16:56:30,395 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 111
# 2024-11-24 16:56:37,135 [INFO] Getting image description for path images/Astor Manual/page-112/full_page_image.png
# 2024-11-24 16:56:43,287 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:56:43,306 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 112
# 2024-11-24 16:56:46,289 [INFO] Getting image description for path images/Astor Manual/page-113/full_page_image.png
# 2024-11-24 16:56:50,683 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:56:50,693 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 113
# 2024-11-24 16:57:05,356 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 114
# 2024-11-24 16:57:14,556 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 115
# 2024-11-24 16:57:26,538 [INFO] Getting image description for path images/Astor Manual/page-116/full_page_image.png
# 2024-11-24 16:57:31,980 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:57:31,986 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 116
# 2024-11-24 16:57:46,561 [INFO] Getting image description for path images/Astor Manual/page-117/full_page_image.png
# 2024-11-24 16:57:52,999 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:57:53,022 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 117
# 2024-11-24 16:58:04,432 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 118
# 2024-11-24 16:58:17,063 [INFO] Getting image description for path images/Astor Manual/page-119/full_page_image.png
# 2024-11-24 16:58:23,667 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:58:23,684 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 119
# 2024-11-24 16:58:32,303 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 120
# 2024-11-24 16:58:43,873 [INFO] Getting image description for path images/Astor Manual/page-121/full_page_image.png
# 2024-11-24 16:58:50,367 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:58:50,371 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 121
# 2024-11-24 16:59:01,551 [INFO] Getting image description for path images/Astor Manual/page-122/full_page_image.png
# 2024-11-24 16:59:07,144 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:59:07,158 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 122
# 2024-11-24 16:59:12,490 [INFO] Getting image description for path images/Astor Manual/page-123/full_page_image.png
# 2024-11-24 16:59:18,072 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:59:18,086 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 123
# 2024-11-24 16:59:30,261 [INFO] Getting image description for path images/Astor Manual/page-124/full_page_image.png
# 2024-11-24 16:59:36,097 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:59:36,107 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 124
# 2024-11-24 16:59:49,784 [INFO] Getting image description for path images/Astor Manual/page-125/full_page_image.png
# 2024-11-24 16:59:56,594 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 16:59:56,600 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 125
# 2024-11-24 17:00:07,933 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 126
# 2024-11-24 17:00:14,858 [INFO] Getting image description for path images/Astor Manual/page-127/full_page_image.png
# 2024-11-24 17:00:20,177 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:00:20,188 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 127
# 2024-11-24 17:00:31,215 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 128
# 2024-11-24 17:00:41,796 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 129
# 2024-11-24 17:00:52,143 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 130
# 2024-11-24 17:00:58,137 [INFO] Getting image description for path images/Astor Manual/page-131/full_page_image.png
# 2024-11-24 17:01:10,130 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:01:10,149 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 131
# 2024-11-24 17:01:14,251 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 132
# 2024-11-24 17:01:22,208 [INFO] Getting image description for path images/Astor Manual/page-133/full_page_image.png
# 2024-11-24 17:01:28,421 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:01:28,425 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 133
# 2024-11-24 17:01:38,257 [INFO] Getting image description for path images/Astor Manual/page-134/full_page_image.png
# 2024-11-24 17:01:43,788 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:01:43,800 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 134
# 2024-11-24 17:01:58,828 [INFO] Getting image description for path images/Astor Manual/page-135/full_page_image.png
# 2024-11-24 17:02:05,247 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:02:05,272 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 135
# 2024-11-24 17:02:18,987 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 136
# 2024-11-24 17:02:28,474 [INFO] Getting image description for path images/Astor Manual/page-137/full_page_image.png
# 2024-11-24 17:02:42,748 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:02:42,755 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 137
# 2024-11-24 17:02:51,492 [INFO] Getting image description for path images/Astor Manual/page-138/full_page_image.png
# 2024-11-24 17:02:57,261 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:02:57,266 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 138
# 2024-11-24 17:03:05,322 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 139
# 2024-11-24 17:03:10,621 [INFO] Getting image description for path images/Astor Manual/page-140/full_page_image.png
# 2024-11-24 17:03:16,950 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:03:16,956 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 140
# 2024-11-24 17:03:19,663 [INFO] Getting image description for path images/Astor Manual/page-141/full_page_image.png
# 2024-11-24 17:03:24,372 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:03:24,384 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 141
# 2024-11-24 17:03:29,729 [INFO] Getting image description for path images/Astor Manual/page-142/full_page_image.png
# 2024-11-24 17:03:36,819 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:03:36,829 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 142
# 2024-11-24 17:03:46,070 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 143
# 2024-11-24 17:03:53,057 [INFO] Getting image description for path images/Astor Manual/page-144/full_page_image.png
# 2024-11-24 17:03:59,372 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:03:59,381 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 144
# 2024-11-24 17:04:10,618 [INFO] Getting image description for path images/Astor Manual/page-145/full_page_image.png
# 2024-11-24 17:04:15,811 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:04:15,826 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 145
# 2024-11-24 17:04:27,679 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 146
# 2024-11-24 17:04:38,273 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 147
# 2024-11-24 17:04:49,892 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 148
# 2024-11-24 17:05:03,806 [INFO] Getting image description for path images/Astor Manual/page-149/full_page_image.png
# 2024-11-24 17:05:08,358 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:05:08,375 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 149
# 2024-11-24 17:05:18,306 [INFO] Getting image description for path images/Astor Manual/page-150/full_page_image.png
# 2024-11-24 17:05:24,748 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:05:24,759 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 150
# 2024-11-24 17:05:35,115 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 151
# 2024-11-24 17:05:45,777 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 152
# 2024-11-24 17:05:54,433 [INFO] Getting image description for path images/Astor Manual/page-153/full_page_image.png
# 2024-11-24 17:06:00,773 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:06:00,784 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 153
# 2024-11-24 17:06:12,641 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 154
# 2024-11-24 17:06:26,448 [INFO] Getting image description for path images/Astor Manual/page-155/full_page_image.png
# 2024-11-24 17:06:32,806 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:06:32,819 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 155
# 2024-11-24 17:06:47,457 [INFO] Getting image description for path images/Astor Manual/page-156/full_page_image.png
# 2024-11-24 17:06:57,945 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:06:57,953 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 156
# 2024-11-24 17:07:01,301 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 157
# 2024-11-24 17:07:11,956 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 158
# 2024-11-24 17:07:24,542 [INFO] Getting image description for path images/Astor Manual/page-159/full_page_image.png
# 2024-11-24 17:07:30,498 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:07:30,502 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 159
# 2024-11-24 17:07:40,782 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 160
# 2024-11-24 17:07:50,923 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 161
# 2024-11-24 17:08:02,983 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 162
# 2024-11-24 17:08:09,359 [INFO] Getting image description for path images/Astor Manual/page-163/full_page_image.png
# 2024-11-24 17:08:15,136 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:08:15,148 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 163
# 2024-11-24 17:08:24,726 [INFO] Getting image description for path images/Astor Manual/page-164/full_page_image.png
# 2024-11-24 17:08:30,368 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:08:30,375 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 164
# 2024-11-24 17:08:39,907 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 165
# 2024-11-24 17:08:47,680 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 166
# 2024-11-24 17:08:56,341 [INFO] Getting image description for path images/Astor Manual/page-167/full_page_image.png
# 2024-11-24 17:09:02,928 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:09:02,938 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 167
# 2024-11-24 17:09:16,297 [INFO] Getting image description for path images/Astor Manual/page-168/full_page_image.png
# 2024-11-24 17:09:22,297 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:09:22,307 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 168
# 2024-11-24 17:09:34,669 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 169
# 2024-11-24 17:09:40,543 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 170
# 2024-11-24 17:09:54,339 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 171
# 2024-11-24 17:10:03,732 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 172
# 2024-11-24 17:10:18,282 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 173
# 2024-11-24 17:10:29,914 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 174
# 2024-11-24 17:10:44,072 [INFO] Getting image description for path images/Astor Manual/page-175/full_page_image.png
# 2024-11-24 17:10:51,177 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:10:51,184 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 175
# 2024-11-24 17:11:05,464 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 176
# 2024-11-24 17:11:10,749 [INFO] Getting image description for path images/Astor Manual/page-177/full_page_image.png
# 2024-11-24 17:11:16,693 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:11:16,708 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 177
# 2024-11-24 17:11:27,661 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 178
# 2024-11-24 17:11:36,233 [INFO] Getting image description for path images/Astor Manual/page-179/full_page_image.png
# 2024-11-24 17:11:41,926 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:11:41,938 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 179
# 2024-11-24 17:11:48,184 [INFO] Getting image description for path images/Astor Manual/page-180/full_page_image.png
# 2024-11-24 17:11:53,121 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:11:53,126 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 180
# 2024-11-24 17:12:03,112 [INFO] Getting image description for path images/Astor Manual/page-181/full_page_image.png
# 2024-11-24 17:12:09,671 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:12:09,683 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 181
# 2024-11-24 17:12:21,793 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 182
# 2024-11-24 17:12:31,967 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 183
# 2024-11-24 17:12:46,123 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 184
# 2024-11-24 17:12:50,303 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 185
# 2024-11-24 17:12:53,550 [INFO] Getting image description for path images/Astor Manual/page-186/full_page_image.png
# 2024-11-24 17:12:58,848 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:12:58,861 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 186
# 2024-11-24 17:13:06,789 [INFO] Getting image description for path images/Astor Manual/page-187/full_page_image.png
# 2024-11-24 17:13:12,176 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:13:12,189 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 187
# 2024-11-24 17:13:18,065 [INFO] Getting image description for path images/Astor Manual/page-188/full_page_image.png
# 2024-11-24 17:13:23,052 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:13:23,062 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 188
# 2024-11-24 17:13:33,341 [INFO] Getting image description for path images/Astor Manual/page-189/full_page_image.png
# 2024-11-24 17:13:38,873 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:13:38,883 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 189
# 2024-11-24 17:13:52,164 [INFO] Getting image description for path images/Astor Manual/page-190/full_page_image.png
# 2024-11-24 17:13:56,859 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:13:56,875 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 190
# 2024-11-24 17:14:11,124 [INFO] Getting image description for path images/Astor Manual/page-191/full_page_image.png
# 2024-11-24 17:14:15,961 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:14:15,977 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 191
# 2024-11-24 17:14:29,130 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 192
# 2024-11-24 17:14:40,376 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 193
# 2024-11-24 17:14:53,892 [INFO] Getting image description for path images/Astor Manual/page-194/full_page_image.png
# 2024-11-24 17:14:58,420 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:14:58,428 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 194
# 2024-11-24 17:15:01,319 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 195
# 2024-11-24 17:15:15,087 [INFO] Getting image description for path images/Astor Manual/page-196/full_page_image.png
# 2024-11-24 17:15:20,837 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:15:20,849 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 196
# 2024-11-24 17:15:35,171 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 197
# 2024-11-24 17:15:37,970 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 198
# 2024-11-24 17:15:42,762 [INFO] Getting image description for path images/Astor Manual/page-199/full_page_image.png
# 2024-11-24 17:15:48,230 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:15:48,243 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 199
# 2024-11-24 17:16:00,786 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 200
# 2024-11-24 17:16:06,293 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 201
# 2024-11-24 17:16:14,772 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 202
# 2024-11-24 17:16:25,236 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 203
# 2024-11-24 17:16:39,333 [INFO] Getting image description for path images/Astor Manual/page-204/full_page_image.png
# 2024-11-24 17:16:45,738 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:16:45,762 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 204
# 2024-11-24 17:16:56,223 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 205
# 2024-11-24 17:17:00,185 [INFO] Getting image description for path images/Astor Manual/page-206/full_page_image.png
# 2024-11-24 17:17:03,675 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:17:03,693 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 206
# 2024-11-24 17:17:07,698 [INFO] Getting image description for path images/Astor Manual/page-207/full_page_image.png
# 2024-11-24 17:17:11,695 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:17:11,708 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 207
# 2024-11-24 17:17:19,245 [INFO] Getting image description for path images/Astor Manual/page-208/full_page_image.png
# 2024-11-24 17:17:24,530 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:17:24,549 [INFO] Ruuning for PDF : source_data/Astor Manual.pdf and page number 208
# ...
# 2024-11-24 17:48:44,062 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 80
# 2024-11-24 17:48:50,869 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-81/full_page_image.png
# 2024-11-24 17:48:56,768 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:48:56,782 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 81
# 2024-11-24 17:49:04,314 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 82
# 2024-11-24 17:49:18,022 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 83
# 2024-11-24 17:49:31,830 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-84/full_page_image.png
# 2024-11-24 17:49:36,411 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:49:36,424 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 84
# 2024-11-24 17:49:42,652 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-85/full_page_image.png
# 2024-11-24 17:49:47,168 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:49:47,189 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 85
# 2024-11-24 17:50:02,290 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-86/full_page_image.png
# 2024-11-24 17:50:07,565 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:50:07,576 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 86
# 2024-11-24 17:50:22,395 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-87/full_page_image.png
# 2024-11-24 17:50:26,902 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:50:26,907 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 87
# 2024-11-24 17:50:34,995 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-88/full_page_image.png
# 2024-11-24 17:50:40,364 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:50:40,371 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 88
# 2024-11-24 17:50:52,600 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-89/full_page_image.png
# 2024-11-24 17:50:58,775 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:50:58,785 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 89
# 2024-11-24 17:51:09,355 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 90
# 2024-11-24 17:51:19,896 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-91/full_page_image.png
# 2024-11-24 17:51:24,725 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:51:24,734 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 91
# 2024-11-24 17:51:30,818 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-92/full_page_image.png
# 2024-11-24 17:51:36,661 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:51:36,675 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 92
# 2024-11-24 17:51:44,344 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-93/full_page_image.png
# 2024-11-24 17:51:49,503 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:51:49,517 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 93
# 2024-11-24 17:52:02,815 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-94/full_page_image.png
# 2024-11-24 17:52:11,670 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:52:11,678 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 94
# 2024-11-24 17:52:25,211 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 95
# 2024-11-24 17:52:38,962 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-96/full_page_image.png
# 2024-11-24 17:52:44,802 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:52:44,813 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 96
# 2024-11-24 17:52:47,268 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 97
# 2024-11-24 17:52:58,024 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 98
# 2024-11-24 17:53:03,018 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-99/full_page_image.png
# 2024-11-24 17:53:09,271 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:53:09,287 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 99
# 2024-11-24 17:53:13,568 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-100/full_page_image.png
# 2024-11-24 17:53:18,348 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:53:18,363 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 100
# 2024-11-24 17:53:22,117 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-101/full_page_image.png
# 2024-11-24 17:53:26,084 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:53:26,094 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 101
# 2024-11-24 17:53:35,870 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-102/full_page_image.png
# 2024-11-24 17:53:42,050 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:53:42,057 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 102
# 2024-11-24 17:53:52,815 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 103
# 2024-11-24 17:54:06,860 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 104
# 2024-11-24 17:54:12,592 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 105
# 2024-11-24 17:54:21,281 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 106
# 2024-11-24 17:54:24,089 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-107/full_page_image.png
# 2024-11-24 17:54:30,204 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:54:30,212 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 107
# 2024-11-24 17:54:34,007 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-108/full_page_image.png
# 2024-11-24 17:54:38,508 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:54:38,518 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 108
# 2024-11-24 17:54:43,159 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-109/full_page_image.png
# 2024-11-24 17:54:48,180 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:54:48,184 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 109
# 2024-11-24 17:55:02,776 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-110/full_page_image.png
# 2024-11-24 17:55:08,019 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:55:08,036 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 110
# 2024-11-24 17:55:18,476 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 111
# 2024-11-24 17:55:24,106 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-112/full_page_image.png
# 2024-11-24 17:55:28,935 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:55:28,942 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 112
# 2024-11-24 17:55:42,615 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-113/full_page_image.png
# 2024-11-24 17:55:46,819 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:55:46,826 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 113
# 2024-11-24 17:55:50,105 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-114/full_page_image.png
# 2024-11-24 17:55:55,178 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:55:55,194 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 114
# 2024-11-24 17:55:59,807 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-115/full_page_image.png
# 2024-11-24 17:56:03,389 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:56:03,419 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 115
# 2024-11-24 17:56:16,958 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-116/full_page_image.png
# 2024-11-24 17:56:22,594 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:56:22,599 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 116
# 2024-11-24 17:56:37,004 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-117/full_page_image.png
# 2024-11-24 17:56:40,784 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:56:40,789 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 117
# 2024-11-24 17:56:49,989 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 118
# 2024-11-24 17:57:04,797 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 119
# 2024-11-24 17:57:17,891 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 120
# 2024-11-24 17:57:31,239 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 121
# 2024-11-24 17:57:44,166 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 122
# 2024-11-24 17:57:46,403 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 123
# 2024-11-24 17:58:00,230 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 124
# 2024-11-24 17:58:08,613 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 125
# 2024-11-24 17:58:23,624 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 126
# 2024-11-24 17:58:29,048 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 127
# 2024-11-24 17:58:42,329 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 128
# 2024-11-24 17:58:50,231 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 129
# 2024-11-24 17:59:04,572 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 130
# 2024-11-24 17:59:18,192 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 131
# 2024-11-24 17:59:20,503 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-132/full_page_image.png
# 2024-11-24 17:59:24,440 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:59:24,466 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 132
# 2024-11-24 17:59:26,875 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-133/full_page_image.png
# 2024-11-24 17:59:32,292 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 17:59:32,314 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 133
# 2024-11-24 17:59:46,966 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 134
# 2024-11-24 17:59:59,273 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-135/full_page_image.png
# 2024-11-24 18:00:03,108 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:00:03,113 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 135
# 2024-11-24 18:00:12,882 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 136
# 2024-11-24 18:00:22,887 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-137/full_page_image.png
# 2024-11-24 18:00:27,814 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:00:27,820 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 137
# 2024-11-24 18:00:38,966 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 138
# 2024-11-24 18:00:47,549 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-139/full_page_image.png
# 2024-11-24 18:00:52,212 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:00:52,228 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 139
# 2024-11-24 18:00:59,962 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 140
# 2024-11-24 18:01:12,903 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 141
# 2024-11-24 18:01:21,258 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-142/full_page_image.png
# 2024-11-24 18:01:25,840 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:01:25,852 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 142
# 2024-11-24 18:01:35,352 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 143
# 2024-11-24 18:01:43,573 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-144/full_page_image.png
# 2024-11-24 18:01:49,424 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:01:49,432 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 144
# 2024-11-24 18:01:58,309 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 145
# 2024-11-24 18:02:05,364 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 146
# 2024-11-24 18:02:18,323 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 147
# 2024-11-24 18:02:33,092 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 148
# 2024-11-24 18:02:44,628 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 149
# 2024-11-24 18:02:59,205 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 150
# 2024-11-24 18:03:06,312 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 151
# 2024-11-24 18:03:22,492 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-152/full_page_image.png
# 2024-11-24 18:03:32,881 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-24 18:03:32,897 [INFO] Ruuning for PDF : source_data/APP-TIAGO-FINAL-OMSB.pdf and page number 152
# 2024-11-24 18:03:37,739 [INFO] Getting image description for path images/APP-TIAGO-FINAL-OMSB/page-153/full_page_image.png
# 2024-11-24 18:03:42,181 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processed all PDFs and saved consolidated output: data_parsed/Combined_Output.csv
